# %%
import pandas as pd
import numpy as np
import os
import requests
import yaml

import matplotlib.pyplot as plt

# %%
yaml_path = 'data_for_visualizations.yaml'
with open(yaml_path) as file: 
    yaml_viz = yaml.load(file, Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 yaml_path = 'data_for_visualizations.yaml'
# ----> 2 with open(yaml_path) as file:
#       3     yaml_viz = yaml.load(file, Loader=yaml.FullLoader)
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_for_visualizations.yaml'

# %% [markdown]
# ## Get latest data

# %%
import update_crv_virtualprice as vp
import update_cvx_token_supply as ts
import update_cvx_rewardRate as rr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import update_crv_virtualprice as vp
#       2 import update_cvx_token_supply as ts
#       3 import update_cvx_rewardRate as rr
#
# File ~/Projects/apy-analytics/scripts/update_crv_virtualprice.py:1
# ----> 1 from brownie import network, accounts, Contract, chain
#       2 import brownie
#       3 from brownie import web3
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eth_brownie-1.19.3-py3.9.egg/brownie/__init__.py:6
#       1 #!/usr/bin/python3
#       3 """
#       4 isort:skip_file
#       5 """
# ----> 6 from brownie.project import compile_source, run
#       7 from brownie._config import CONFIG as _CONFIG
#       8 from brownie.convert import Fixed, Wei
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eth_brownie-1.19.3-py3.9.egg/brownie/project/__init__.py:3
#       1 #!/usr/bin/python3
# ----> 3 from .main import (  # NOQA 401
#       4     check_for_project,
#       5     compile_source,
#       6     from_brownie_mix,
#       7     from_ethpm,
#       8     get_loaded_projects,
#       9     load,
#      10     new,
#      11 )
#      12 from .scripts import run
#      14 __all__ = ["run"]
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eth_brownie-1.19.3-py3.9.egg/brownie/project/main.py:45
#      36 from brownie._expansion import expand_posix_vars
#      37 from brownie.exceptions import (
#      38     BadProjectName,
#      39     BrownieEnvironmentWarning,
#    (...)
#      43     ProjectNotFound,
#      44 )
# ---> 45 from brownie.network import web3
#      46 from brownie.network.contract import (
#      47     Contract,
#      48     ContractContainer,
#      49     InterfaceContainer,
#      50     ProjectContract,
#      51 )
#      52 from brownie.network.state import _add_contract, _remove_contract, _revert_register
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eth_brownie-1.19.3-py3.9.egg/brownie/network/__init__.py:4
#       1 #!/usr/bin/python3
# ----> 4 from .account import Accounts
#       5 from .main import (  # NOQA 401
#       6     connect,
#       7     disconnect,
#    (...)
#      13     show_active,
#      14 )
#      15 from .rpc import Rpc
#
# File ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eth_brownie-1.19.3-py3.9.egg/brownie/network/account.py:16
#      14 import eth_keys
#      15 import rlp
# ---> 16 from eip712.messages import EIP712Message, _hash_eip191_message
#      17 from eth_account._utils.signing import sign_message_hash
#      18 from eth_account.datastructures import SignedMessage
#
# ImportError: cannot import name '_hash_eip191_message' from 'eip712.messages' (/Users/andrewgoldberg/opt/anaconda3/envs/web3/lib/python3.9/site-packages/eip712/messages.py)

# %%
vp.connect()

# %% [markdown]
# ### Start and End blocks for retreival

# %%
# Start block
token_supply_files = [file for file in os.listdir('../data/cvx_token_supply') if file.split('.')[-1] == 'csv']
last_blocks = [file.split('.')[0].split('_')[3] for file in token_supply_files]
last_blocks.sort(reverse=True)
print(f'Last downloaded block: {last_blocks[0]}')
last_dl_block = int(last_blocks[0])

# %%
# End block
print(f'Current Eth block: {vp.chain.height}')
current_eth_block = vp.chain.height
# Out:
# Current Eth block: 16670643

# %%
target_pools = ['alusd', 'susd', 'frax', 'mim', 'ousd', 'ironbank', 'fei', 'ust-wormhole']

# %%
print('retrieving virtual price data')
# vp.main(last_dl_block, current_eth_block)
print('retrieving token supply data')
ts.main()
print('retrieving reward rate and total supply data')
rr.main(last_dl_block, current_eth_block)
# Out:
# retrieving virtual price data
# retrieving token supply data
# contract doesnt exist at block 11565019
# contract doesnt exist at block 11566710
# contract doesnt exist at block 11568270
# contract doesnt exist at block 11569949
# contract doesnt exist at block 11571564
# contract doesnt exist at block 11573230
# contract doesnt exist at block 11574860
# contract doesnt exist at block 11576488
# contract doesnt exist at block 11578165
# contract doesnt exist at block 11579719
# contract doesnt exist at block 11581387
# contract doesnt exist at block 11583018
# contract doesnt exist at block 11584641
# contract doesnt exist at block 11586256
# contract doesnt exist at block 11587855
# contract doesnt exist at block 11589502
# contract doesnt exist at block 11591158
# contract doesnt exist at block 11592771
# contract doesnt exist at block 11594360
# contract doesnt exist at block 11596020
# contract doesnt exist at block 11597690
# contract doesnt exist at block 11599264
# contract doesnt exist at block 11600885
# contract doesnt exist at block 11602551
# contract doesnt exist at block 11604175
# contract doesnt exist at block 11605789
# contract doesnt exist at block 11607424
# contract doesnt exist at block 11609070
# contract doesnt exist at block 11610611
# contract doesnt exist at block 11612265
# contract doesnt exist at block 11613963
# contract doesnt exist at block 11615571
# contract doesnt exist at block 11617204
# contract doesnt exist at block 11618854
# contract doesnt exist at block 11620424
# contract doesnt exist at block 11622057
# contract doesnt exist at block 11623680
# contract doesnt exist at block 11625305
# contract doesnt exist at block 11626976
# contract doesnt exist at block 11628624
# contract doesnt exist at block 11630234
# contract doesnt exist at block 11631821
# contract doesnt exist at block 11633495
# contract doesnt exist at block 11635129
# contract doesnt exist at block 11636762
# contract doesnt exist at block 11638372
# contract doesnt exist at block 11639978
# contract doesnt exist at block 11641678
# contract doesnt exist at block 11643317
# contract doesnt exist at block 11644885
# contract doesnt exist at block 11646463
# contract doesnt exist at block 11648178
# contract doesnt exist at block 11649878
# contract doesnt exist at block 11651490
# contract doesnt exist at block 11653086
# contract doesnt exist at block 11654706
# contract doesnt exist at block 11656284
# contract doesnt exist at block 11657895
# contract doesnt exist at block 11659571
# contract doesnt exist at block 11661244
# contract doesnt exist at block 11662865
# contract doesnt exist at block 11664562
# contract doesnt exist at block 11666129
# contract doesnt exist at block 11667716
# contract doesnt exist at block 11669373
# contract doesnt exist at block 11670975
# contract doesnt exist at block 11672565
# contract doesnt exist at block 11674209
# contract doesnt exist at block 11675867
# contract doesnt exist at block 11677496
# contract doesnt exist at block 11679132
# contract doesnt exist at block 11680738
# contract doesnt exist at block 11682363
# contract doesnt exist at block 11683995
# contract doesnt exist at block 11685612
# contract doesnt exist at block 11687235
# contract doesnt exist at block 11688896
# contract doesnt exist at block 11690518
# contract doesnt exist at block 11692158
# contract doesnt exist at block 11693842
# contract doesnt exist at block 11695474
# contract doesnt exist at block 11697041
# contract doesnt exist at block 11698657
# contract doesnt exist at block 11700293
# contract doesnt exist at block 11701952
# contract doesnt exist at block 11703563
# contract doesnt exist at block 11705158
# contract doesnt exist at block 11706796
# contract doesnt exist at block 11708433
# contract doesnt exist at block 11710085
# contract doesnt exist at block 11711687
# contract doesnt exist at block 11713305
# contract doesnt exist at block 11714974
# contract doesnt exist at block 11716609
# contract doesnt exist at block 11718184
# contract doesnt exist at block 11719834
# contract doesnt exist at block 11721455
# contract doesnt exist at block 11723083
# contract doesnt exist at block 11724704
# contract doesnt exist at block 11726378
# contract doesnt exist at block 11727979
# contract doesnt exist at block 11729582
# contract doesnt exist at block 11731148
# contract doesnt exist at block 11732866
# contract doesnt exist at block 11734493
# contract doesnt exist at block 11736080
# contract doesnt exist at block 11737695
# contract doesnt exist at block 11739357
# contract doesnt exist at block 11740961
# contract doesnt exist at block 11742594
# contract doesnt exist at block 11744156
# contract doesnt exist at block 11745801
# contract doesnt exist at block 11747459
# contract doesnt exist at block 11749061
# contract doesnt exist at block 11750682
# contract doesnt exist at block 11752287
# contract doesnt exist at block 11753912
# contract doesnt exist at block 11755553
# contract doesnt exist at block 11757125
# contract doesnt exist at block 11758753
# contract doesnt exist at block 11760302
# contract doesnt exist at block 11761995
# contract doesnt exist at block 11763672
# contract doesnt exist at block 11765289
# contract doesnt exist at block 11766939
# contract doesnt exist at block 11768588
# contract doesnt exist at block 11770195
# contract doesnt exist at block 11771829
# contract doesnt exist at block 11773428
# contract doesnt exist at block 11775084
# contract doesnt exist at block 11776684
# contract doesnt exist at block 11778316
# contract doesnt exist at block 11779922
# contract doesnt exist at block 11781553
# contract doesnt exist at block 11783175
# contract doesnt exist at block 11784765
# contract doesnt exist at block 11786406
# contract doesnt exist at block 11787996
# contract doesnt exist at block 11789662
# contract doesnt exist at block 11791296
# contract doesnt exist at block 11792922
# contract doesnt exist at block 11794518
# contract doesnt exist at block 11796108
# contract doesnt exist at block 11797793
# contract doesnt exist at block 11799369
# contract doesnt exist at block 11801021
# contract doesnt exist at block 11802629
# contract doesnt exist at block 11804242
# contract doesnt exist at block 11805888
# contract doesnt exist at block 11807548
# contract doesnt exist at block 11809124
# contract doesnt exist at block 11810811
# contract doesnt exist at block 11812442
# contract doesnt exist at block 11814030
# contract doesnt exist at block 11815693
# contract doesnt exist at block 11817315
# contract doesnt exist at block 11818910
# contract doesnt exist at block 11820483
# contract doesnt exist at block 11822112
# contract doesnt exist at block 11823791
# contract doesnt exist at block 11825395
# contract doesnt exist at block 11827016
# contract doesnt exist at block 11828623
# contract doesnt exist at block 11830251
# contract doesnt exist at block 11831923
# contract doesnt exist at block 11833528
# contract doesnt exist at block 11835131
# contract doesnt exist at block 11836765
# contract doesnt exist at block 11838440
# contract doesnt exist at block 11840049
# contract doesnt exist at block 11841677
# contract doesnt exist at block 11843321
# contract doesnt exist at block 11844964
# contract doesnt exist at block 11846583
# contract doesnt exist at block 11848165
# contract doesnt exist at block 11849782
# contract doesnt exist at block 11851387
# contract doesnt exist at block 11853091
# contract doesnt exist at block 11854684
# contract doesnt exist at block 11856305
# contract doesnt exist at block 11857946
# contract doesnt exist at block 11859580
# contract doesnt exist at block 11861211
# contract doesnt exist at block 11862856
# contract doesnt exist at block 11864442
# contract doesnt exist at block 11866052
# contract doesnt exist at block 11867673
# contract doesnt exist at block 11869338
# contract doesnt exist at block 11870927
# contract doesnt exist at block 11872543
# contract doesnt exist at block 11874240
# contract doesnt exist at block 11875848
# contract doesnt exist at block 11877476
# contract doesnt exist at block 11879089
# contract doesnt exist at block 11880709
# contract doesnt exist at block 11882296
# contract doesnt exist at block 11883923
# contract doesnt exist at block 11885565
# contract doesnt exist at block 11887226
# contract doesnt exist at block 11888849
# contract doesnt exist at block 11890500
# contract doesnt exist at block 11892107
# contract doesnt exist at block 11893688
# contract doesnt exist at block 11895291
# contract doesnt exist at block 11896995
# contract doesnt exist at block 11898552
# contract doesnt exist at block 11900130
# contract doesnt exist at block 11901789
# contract doesnt exist at block 11903480
# contract doesnt exist at block 11905113
# contract doesnt exist at block 11906685
# contract doesnt exist at block 11908338
# contract doesnt exist at block 11909976
# contract doesnt exist at block 11911545
# contract doesnt exist at block 11913161
# contract doesnt exist at block 11914861
# contract doesnt exist at block 11916478
# contract doesnt exist at block 11918119
# contract doesnt exist at block 11919704
# contract doesnt exist at block 11921313
# contract doesnt exist at block 11922947
# contract doesnt exist at block 11924538
# contract doesnt exist at block 11926224
# contract doesnt exist at block 11927804
# contract doesnt exist at block 11929462
# contract doesnt exist at block 11931065
# contract doesnt exist at block 11932712
# contract doesnt exist at block 11934344
# contract doesnt exist at block 11936004
# contract doesnt exist at block 11937608
# contract doesnt exist at block 11939222
# contract doesnt exist at block 11940820
# contract doesnt exist at block 11942493
# contract doesnt exist at block 11944108
# contract doesnt exist at block 11945676
# contract doesnt exist at block 11947300
# contract doesnt exist at block 11948960
# contract doesnt exist at block 11950578
# contract doesnt exist at block 11952201
# contract doesnt exist at block 11953797
# contract doesnt exist at block 11955436
# contract doesnt exist at block 11957060
# contract doesnt exist at block 11958688
# contract doesnt exist at block 11960350
# contract doesnt exist at block 11961986
# contract doesnt exist at block 11963551
# contract doesnt exist at block 11965141
# contract doesnt exist at block 11966814
# contract doesnt exist at block 11968394
# contract doesnt exist at block 11970041
# contract doesnt exist at block 11971656
# contract doesnt exist at block 11973294
# contract doesnt exist at block 11974909
# contract doesnt exist at block 11976566
# contract doesnt exist at block 11978156
# contract doesnt exist at block 11979827
# contract doesnt exist at block 11981434
# contract doesnt exist at block 11983083
# contract doesnt exist at block 11984733
# contract doesnt exist at block 11986396
# contract doesnt exist at block 11987997
# contract doesnt exist at block 11989604
# contract doesnt exist at block 11991216
# contract doesnt exist at block 11992809
# contract doesnt exist at block 11994474
# contract doesnt exist at block 11996131
# contract doesnt exist at block 11997725
# contract doesnt exist at block 11999326
# contract doesnt exist at block 12000974
# contract doesnt exist at block 12002571
# contract doesnt exist at block 12004180
# contract doesnt exist at block 12005798
# contract doesnt exist at block 12007407
# contract doesnt exist at block 12009034
# contract doesnt exist at block 12010667
# contract doesnt exist at block 12012281
# contract doesnt exist at block 12013939
# contract doesnt exist at block 12015560
# contract doesnt exist at block 12017167
# contract doesnt exist at block 12018758
# contract doesnt exist at block 12020354
# contract doesnt exist at block 12021995
# contract doesnt exist at block 12023552
# contract doesnt exist at block 12025162
# contract doesnt exist at block 12026824
# contract doesnt exist at block 12028405
# contract doesnt exist at block 12030081
# contract doesnt exist at block 12031758
# contract doesnt exist at block 12033336
# contract doesnt exist at block 12034928
# contract doesnt exist at block 12036542
# contract doesnt exist at block 12038181
# contract doesnt exist at block 12039858
# contract doesnt exist at block 12041420
# contract doesnt exist at block 12043055
# contract doesnt exist at block 12044675
# contract doesnt exist at block 12046295
# contract doesnt exist at block 12047924
# contract doesnt exist at block 12049505
# contract doesnt exist at block 12051142
# contract doesnt exist at block 12052815
# contract doesnt exist at block 12054413
# contract doesnt exist at block 12056038
# contract doesnt exist at block 12057676
# contract doesnt exist at block 12059299
# contract doesnt exist at block 12060876
# contract doesnt exist at block 12062516
# contract doesnt exist at block 12064162
# contract doesnt exist at block 12065800
# contract doesnt exist at block 12067446
# contract doesnt exist at block 12069048
# contract doesnt exist at block 12070706
# contract doesnt exist at block 12072306
# contract doesnt exist at block 12073959
# contract doesnt exist at block 12075574
# contract doesnt exist at block 12077187
# contract doesnt exist at block 12078833
# contract doesnt exist at block 12080404
# contract doesnt exist at block 12082009
# contract doesnt exist at block 12083661
# contract doesnt exist at block 12085254
# contract doesnt exist at block 12086855
# contract doesnt exist at block 12088505
# contract doesnt exist at block 12090115
# contract doesnt exist at block 12091744
# contract doesnt exist at block 12093357
# contract doesnt exist at block 12095001
# contract doesnt exist at block 12096635
# contract doesnt exist at block 12098249
# contract doesnt exist at block 12099861
# contract doesnt exist at block 12101413
# contract doesnt exist at block 12103081
# contract doesnt exist at block 12104733
# contract doesnt exist at block 12106355
# contract doesnt exist at block 12107963
# contract doesnt exist at block 12109585
# contract doesnt exist at block 12111247
# contract doesnt exist at block 12112877
# contract doesnt exist at block 12114509
# contract doesnt exist at block 12116135
# contract doesnt exist at block 12117786
# contract doesnt exist at block 12119397
# contract doesnt exist at block 12120948
# contract doesnt exist at block 12122604
# contract doesnt exist at block 12124271
# contract doesnt exist at block 12125877
# contract doesnt exist at block 12127480
# contract doesnt exist at block 12129129
# contract doesnt exist at block 12130764
# contract doesnt exist at block 12132392
# contract doesnt exist at block 12134015
# contract doesnt exist at block 12135649
# contract doesnt exist at block 12137275
# contract doesnt exist at block 12138884
# contract doesnt exist at block 12140488
# contract doesnt exist at block 12142093
# contract doesnt exist at block 12143793
# contract doesnt exist at block 12145402
# contract doesnt exist at block 12146990
# contract doesnt exist at block 12148628
# contract doesnt exist at block 12150245
# contract doesnt exist at block 12151878
# contract doesnt exist at block 12153469
# contract doesnt exist at block 12155075
# contract doesnt exist at block 12156761
# contract doesnt exist at block 12158376
# contract doesnt exist at block 12159954
# contract doesnt exist at block 12161567
# contract doesnt exist at block 12163215
# contract doesnt exist at block 12164889
# contract doesnt exist at block 12166460
# contract doesnt exist at block 12168103
# contract doesnt exist at block 12169742
# contract doesnt exist at block 12171355
# contract doesnt exist at block 12172969
# contract doesnt exist at block 12174637
# contract doesnt exist at block 12176303
# contract doesnt exist at block 12177907
# contract doesnt exist at block 12179544
# contract doesnt exist at block 12181133
# contract doesnt exist at block 12182813
# contract doesnt exist at block 12184372
# contract doesnt exist at block 12186031
# contract doesnt exist at block 12187671
# contract doesnt exist at block 12189296
# contract doesnt exist at block 12190956
# contract doesnt exist at block 12192531
# contract doesnt exist at block 12194186
# contract doesnt exist at block 12195833
# contract doesnt exist at block 12197435
# contract doesnt exist at block 12199010
# contract doesnt exist at block 12200673
# contract doesnt exist at block 12202288
# contract doesnt exist at block 12203903
# contract doesnt exist at block 12205519
# contract doesnt exist at block 12207143
# contract doesnt exist at block 12208745
# contract doesnt exist at block 12210396
# contract doesnt exist at block 12212021
# contract doesnt exist at block 12213671
# contract doesnt exist at block 12215327
# contract doesnt exist at block 12216884
# contract doesnt exist at block 12218485
# contract doesnt exist at block 12220184
# contract doesnt exist at block 12221873
# contract doesnt exist at block 12223496
# contract doesnt exist at block 12225121
# contract doesnt exist at block 12226710
# contract doesnt exist at block 12228389
# contract doesnt exist at block 12229998
# contract doesnt exist at block 12231602
# contract doesnt exist at block 12233232
# contract doesnt exist at block 12234863
# contract doesnt exist at block 12236486
# contract doesnt exist at block 12238061
# contract doesnt exist at block 12239696
# contract doesnt exist at block 12241312
# contract doesnt exist at block 12242914
# contract doesnt exist at block 12244516
# contract doesnt exist at block 12246166
# contract doesnt exist at block 12247812
# contract doesnt exist at block 12249347
# contract doesnt exist at block 12250978
# contract doesnt exist at block 12252617
# contract doesnt exist at block 12254245
# contract doesnt exist at block 12255862
# contract doesnt exist at block 12257477
# contract doesnt exist at block 12259089
# contract doesnt exist at block 12260712
# contract doesnt exist at block 12262367
# contract doesnt exist at block 12263957
# contract doesnt exist at block 12265576
# contract doesnt exist at block 12267213
# contract doesnt exist at block 12268776
# contract doesnt exist at block 12270368
# contract doesnt exist at block 12271969
# contract doesnt exist at block 12273613
# contract doesnt exist at block 12275273
# contract doesnt exist at block 12276891
# contract doesnt exist at block 12278533
# contract doesnt exist at block 12280193
# contract doesnt exist at block 12281840
# contract doesnt exist at block 12283448
# contract doesnt exist at block 12285026
# contract doesnt exist at block 12286712
# contract doesnt exist at block 12288275
# contract doesnt exist at block 12289865
# contract doesnt exist at block 12291501
# contract doesnt exist at block 12293129
# contract doesnt exist at block 12294723
# contract doesnt exist at block 12296323
# contract doesnt exist at block 12297987
# contract doesnt exist at block 12299579
# contract doesnt exist at block 12301200
# contract doesnt exist at block 12302802
# contract doesnt exist at block 12304429
# contract doesnt exist at block 12306079
# contract doesnt exist at block 12307688
# contract doesnt exist at block 12309324
# contract doesnt exist at block 12310961
# contract doesnt exist at block 12312588
# contract doesnt exist at block 12314189
# contract doesnt exist at block 12315783
# contract doesnt exist at block 12317445
# contract doesnt exist at block 12319059
# contract doesnt exist at block 12320628
# contract doesnt exist at block 12322276
# contract doesnt exist at block 12323940
# contract doesnt exist at block 12325547
# contract doesnt exist at block 12327174
# contract doesnt exist at block 12328821
# contract doesnt exist at block 12330432
# contract doesnt exist at block 12332010
# contract doesnt exist at block 12333626
# contract doesnt exist at block 12335228
# contract doesnt exist at block 12336852
# contract doesnt exist at block 12338494
# contract doesnt exist at block 12340105
# contract doesnt exist at block 12341699
# contract doesnt exist at block 12343296
# contract doesnt exist at block 12344945
# contract doesnt exist at block 12346557
# contract doesnt exist at block 12348161
# contract doesnt exist at block 12349820
# contract doesnt exist at block 12351434
# contract doesnt exist at block 12353029
# contract doesnt exist at block 12354634
# contract doesnt exist at block 12356236
# contract doesnt exist at block 12357852
# contract doesnt exist at block 12359474
# contract doesnt exist at block 12361104
# contract doesnt exist at block 12362734
# contract doesnt exist at block 12364359
# contract doesnt exist at block 12366027
# contract doesnt exist at block 12367618
# contract doesnt exist at block 12369261
# contract doesnt exist at block 12370863
# contract doesnt exist at block 12372489
# contract doesnt exist at block 12374078
# contract doesnt exist at block 12375729
# contract doesnt exist at block 12377381
# contract doesnt exist at block 12379035
# contract doesnt exist at block 12380614
# contract doesnt exist at block 12382220
# contract doesnt exist at block 12383847
# contract doesnt exist at block 12385460
# contract doesnt exist at block 12387011
# contract doesnt exist at block 12388635
# contract doesnt exist at block 12390294
# contract doesnt exist at block 12391917
# contract doesnt exist at block 12393540
# contract doesnt exist at block 12395163
# contract doesnt exist at block 12396780
# contract doesnt exist at block 12398439
# contract doesnt exist at block 12400035
# contract doesnt exist at block 12401642
# contract doesnt exist at block 12403258
# contract doesnt exist at block 12404894
# contract doesnt exist at block 12406483
# contract doesnt exist at block 12408129
# contract doesnt exist at block 12409775
# contract doesnt exist at block 12411386
# contract doesnt exist at block 12413025
# contract doesnt exist at block 12414604
# contract doesnt exist at block 12416222
# contract doesnt exist at block 12417864
# contract doesnt exist at block 12419481
# contract doesnt exist at block 12421029
# contract doesnt exist at block 12422661
# contract doesnt exist at block 12424311
# contract doesnt exist at block 12425908
# contract doesnt exist at block 12427529
# contract doesnt exist at block 12429199
# contract doesnt exist at block 12430767
# block: 14300984, timestamp: 1646136017, totalSupply: 85294357892986882728721054
# block: 14302621, timestamp: 1646157613, totalSupply: 85332416718118476568668866
# block: 14304254, timestamp: 1646179200, totalSupply: 85344997561426009956310311
# block: 14305851, timestamp: 1646200802, totalSupply: 85356174720026789101774150
# block: 14307439, timestamp: 1646222430, totalSupply: 85383048195166568427678586
# block: 14309109, timestamp: 1646244003, totalSupply: 85398456828872812856303406
# block: 14310658, timestamp: 1646265602, totalSupply: 85458829329422441223760415
# block: 14312276, timestamp: 1646287244, totalSupply: 85472842690817263297787979
# block: 14313866, timestamp: 1646308810, totalSupply: 85488726466598896428910447
# block: 14315533, timestamp: 1646330418, totalSupply: 85498441745681539131496415
# block: 14317109, timestamp: 1646352020, totalSupply: 85504473838571434263551221
# block: 14318688, timestamp: 1646373603, totalSupply: 85525430096505059750537298
# block: 14320316, timestamp: 1646395203, totalSupply: 85542268404520571923432571
# block: 14322023, timestamp: 1646416818, totalSupply: 85567593378600903933963019
# block: 14323605, timestamp: 1646438430, totalSupply: 85594503212970866953817697
# block: 14325145, timestamp: 1646460002, totalSupply: 85605285173556775969797978
# block: 14326743, timestamp: 1646481617, totalSupply: 85623796446732141870292329
# block: 14328363, timestamp: 1646503263, totalSupply: 85638489897030994132866873
# block: 14329981, timestamp: 1646524817, totalSupply: 85653060283184264371437217
# block: 14331625, timestamp: 1646546414, totalSupply: 85660252576086914154032087
# block: 14333194, timestamp: 1646568006, totalSupply: 85668627440506956231679046
# block: 14334793, timestamp: 1646589601, totalSupply: 85694923679148765683038473
# block: 14336402, timestamp: 1646611215, totalSupply: 85711042868633338489417012
# block: 14338011, timestamp: 1646632802, totalSupply: 85722334208081103650147294
# block: 14339568, timestamp: 1646654412, totalSupply: 85738798589546890867236461
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/c7/8ppmyxcn6znc4ql4nfmfksy80000gn/T/ipykernel_28181/4224999019.py in <module>
#       2 # vp.main(last_dl_block, current_eth_block)
#       3 print('retrieving token supply data')
# ----> 4 ts.main()
#       5 print('retrieving reward rate and total supply data')
#       6 rr.main(last_dl_block, current_eth_block)
#
# ~/Projects/apy-analytics/scripts/update_cvx_token_supply.py in main()
#      59     cvx_tokensupply_df = pd.DataFrame.from_dict(cvx_token_dict, orient='index')
#      60
# ---> 61     cvx_tokensupply_df.to_csv(f'../data/cvx_tokensupply/cvx_tokensupply_6hourly.csv')
#      62
#      63 if __name__ == "__main__":
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3719         )
#    3720
# -> 3721         return DataFrameRenderer(formatter).to_csv(
#    3722             path_or_buf,
#    3723             lineterminator=lineterminator,
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     733     # Only for write methods
#     734     if "r" not in mode and is_path:
# --> 735         check_parent_directory(str(handle))
#     736
#     737     if compression:
#
# ~/opt/anaconda3/envs/web3/lib/python3.9/site-packages/pandas/io/common.py in check_parent_directory(path)
#     596     parent = Path(path).parent
#     597     if not parent.is_dir():
# --> 598         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     599
#     600
#
# OSError: Cannot save file into a non-existent directory: '../data/cvx_tokensupply'

# %% [markdown]
# # Import and organize historical data

# %%
# targeted_pools = ['frax', 'ousd', 'mim', 'susd', 'alusd', 'ust-wormhole', 'ironbank', 'fei']
# wormhole, ironbank and fei need more work

# %%
token_supply_files = [file for file in os.listdir('../data/cvx_token_supply') if file.split('.')[-1] == 'csv']
token_supply_dict = {}
for csv in token_supply_files:
    token_supply_dict[csv] = pd.read_csv(f'../data/cvx_token_supply/{csv}').rename(columns = {'Unnamed: 0': 'block'})

# %%
cvx_token_supply = pd.concat(token_supply_dict).reset_index().drop(['level_0', 'level_1'], axis = 1).rename(columns = {'totalSupply': 'cvxSupply', 'timeStamp': 'cvsSupply_ts'})
cvx_token_supply = cvx_token_supply.sort_values(by='block', ascending=True).reset_index(drop=True)
cvx_token_supply['cvxSupply'] = cvx_token_supply['cvxSupply'].astype(float)

# %%
virtual_price_csv_dict = {}
reward_supply_csv_dict = {}

virtual_price_df_dict = {}
reward_supply_df_dict = {}
df_dict = {}

for pool in targeted_pools:
    print(pool)
    virtual_price_csv_dict[pool] = {}
    reward_supply_csv_dict[pool] = {}

    virtual_price_files = [file for file in os.listdir(f'../data/virtualPrice/{pool}') if file.split('.')[-1] == 'csv']
    for csv in virtual_price_files:
        virtual_price_csv_dict[pool][csv] = pd.read_csv(f'../data/virtualPrice/{pool}/{csv}').rename(columns = {'Unnamed: 0': 'block'})
    virtual_price_df_dict[pool] = pd.concat(virtual_price_csv_dict[pool]).reset_index().drop(['level_0', 'level_1'], axis = 1).rename(columns = {'timeStamp': 'virtual_price_ts'})
    virtual_price_df_dict[pool]['timestamp'] = virtual_price_df_dict[pool].virtual_price_ts.apply(lambda x: pd.to_datetime(x, unit='s', utc=True))
    virtual_price_df_dict[pool]['date'] = virtual_price_df_dict[pool].virtual_price_ts.apply(lambda x: pd.to_datetime(x, unit='s', utc=True)).dt.date
    virtual_price_df_dict[pool]['date'] = virtual_price_df_dict[pool]['date'].apply(lambda x: x.strftime("%Y-%m-%d"))

        
    reward_supply_files = [file for file in os.listdir(f'../data/rewardRate_totalSupply/{pool}') if file.split('.')[-1] == 'csv']
    for csv in reward_supply_files:
        reward_supply_csv_dict[pool][csv] = pd.read_csv(f'../data/rewardRate_totalSupply/{pool}/{csv}').rename(columns = {'Unnamed: 0': 'block'})
    reward_supply_df_dict[pool] = pd.concat(reward_supply_csv_dict[pool]).reset_index().drop(['level_0', 'level_1', 'timeStamp'], axis = 1)
    
    df_dict[pool] = pd.merge(reward_supply_df_dict[pool], virtual_price_df_dict[pool], how = 'left', on = 'block')
    df_dict[pool] = pd.merge(df_dict[pool], cvx_token_supply, how = 'left', on = 'block')
# Out:
# frax
# ousd
# mim
# susd
# alusd
# ust-wormhole
# ironbank
# fei

# %% [markdown]
# # Calculate APR's

# %%
Decimal = 10 ** 18

crvAddress = "0xD533a949740bb3306d119CC777fa900bA034cd52";
cvxAddress = "0x4e3FBD56CD56c3e72c1403e103b45Db9da5B9D2B";
cvxCrvAddress = "0x62B9c7356A2Dc64a1969e19C23e4f579F9810Aa7";

cliffSize = 100000 # // * 1e18; //new cliff every 100,000 tokens
cliffCount = 1000 # // 1,000 cliffs
maxSupply = 100000000 # // * 1e18; //100 mil max supply

# %%
def getCVXMintAmount(pool_df):
    # //first get total supply
    # cvxSupply =  / Decimal
    # get current cliff
    currentCliff = (pool_df['cvxSupply'] / cliffSize)
    # print(f'currentCliff: {currentCliff}')
    # if current cliff is under the max
    if (currentCliff < cliffCount):
        # get remaining cliffs
        remaining = cliffCount - currentCliff
        # print(f'remaining: {remaining}')
        # multiply ratio of remaining cliffs to total cliffs against amount CRV received
        cvxEarned = pool_df['crvPerYear'] * remaining / cliffCount;

        # double check we have not gone over the max supply
        amountTillMax = maxSupply - pool_df['cvxSupply'];
        if (cvxEarned > amountTillMax):
            cvxEarned = amountTillMax
        return cvxEarned;
    return 0

# %%
def calculate_crv_cvx_perYear(pool_df_dict):
    
    pool_calcs_df_dict = {}

    for pool in pool_df_dict.keys():
        print(pool)
        pool_calcs_df_dict[pool] = pool_df_dict[pool].copy()

        # divide values by 10 ** 18
        pool_calcs_df_dict[pool]['rewardRate'] = pool_calcs_df_dict[pool]['rewardRate'].div(Decimal)
        pool_calcs_df_dict[pool]['totalSupply'] = pool_calcs_df_dict[pool]['totalSupply'].astype(float).div(Decimal)
        pool_calcs_df_dict[pool]['virtualPrice'] = pool_calcs_df_dict[pool]['virtualPrice'].astype(float).div(Decimal)
        pool_calcs_df_dict[pool]['cvxSupply'] = pool_calcs_df_dict[pool]['cvxSupply'].astype(float).div(Decimal)


        # calculations
        pool_calcs_df_dict[pool]['virtualSupply'] = pool_calcs_df_dict[pool]['virtualPrice'] * pool_calcs_df_dict[pool]['totalSupply']
        pool_calcs_df_dict[pool]['crvPerUnderlying'] = pool_calcs_df_dict[pool]['rewardRate'] / pool_calcs_df_dict[pool]['virtualSupply'] 
        pool_calcs_df_dict[pool]['crvPerYear'] = pool_calcs_df_dict[pool]['crvPerUnderlying'] * 86400 * 365
        
        # print(pool_calcs_df_dict[pool].apply(getCVXMintAmount, axis=1))
        
        pool_calcs_df_dict[pool]['cvxPerYear'] = pool_calcs_df_dict[pool].apply(getCVXMintAmount, axis=1)
        
    return(pool_calcs_df_dict)

# %%
# pool_calcs_df_dict = {}

# for pool in df_dict.keys():
#     print(pool)
#     pool_calcs_df_dict[pool] = df_dict[pool].copy()

#     # divide values by 10 ** 18
#     pool_calcs_df_dict[pool]['rewardRate'] = pool_calcs_df_dict[pool]['rewardRate'].div(Decimal)
#     pool_calcs_df_dict[pool]['totalSupply'] = pool_calcs_df_dict[pool]['totalSupply'].astype(float).div(Decimal)
#     pool_calcs_df_dict[pool]['virtualPrice'] = pool_calcs_df_dict[pool]['virtualPrice'].astype(float).div(Decimal)
#     pool_calcs_df_dict[pool]['cvxSupply'] = pool_calcs_df_dict[pool]['cvxSupply'].astype(float).div(Decimal)


#     # calculations
#     pool_calcs_df_dict[pool]['virtualSupply'] = pool_calcs_df_dict[pool]['virtualPrice'] * pool_calcs_df_dict[pool]['totalSupply']
#     pool_calcs_df_dict[pool]['crvPerUnderlying'] = pool_calcs_df_dict[pool]['rewardRate'] / pool_calcs_df_dict[pool]['virtualSupply'] 
#     pool_calcs_df_dict[pool]['crvPerYear'] = pool_calcs_df_dict[pool]['crvPerUnderlying'] * 86400 * 365

# %%
calc_dict = calculate_crv_cvx_perYear(df_dict)
# Out:
# frax
# ousd
# mim
# susd
# alusd
# ust-wormhole
# ironbank
# fei

# %% [markdown]
# ### Get CRV / CVX Historical Pricing

# %%
def get_crv_cvx_historical_price(days=365):
    
    vsCoin = "USD"
    cvx_id = "convex-finance"
    crv_id = "curve-dao-token"

    # current market prices
    # crv_current_url = "https://api.coingecko.com/api/v3/simple/token_price/ethereum?contract_addresses=" + crvAddress + "&vs_currencies=" + vsCoin;
    # cvx_current_url = "https://api.coingecko.com/api/v3/simple/token_price/ethereum?contract_addresses=" + cvxAddress + "&vs_currencies=" + vsCoin;

    # historical market prices
    cvx_hist_url = f"https://api.coingecko.com/api/v3/coins/{cvx_id}/market_chart?vs_currency={vsCoin}&days={days}"
    crv_hist_url = f"https://api.coingecko.com/api/v3/coins/{crv_id}/market_chart?vs_currency={vsCoin}&days={days}"
    
    cvx_hist_price_requests = requests.get(cvx_hist_url)
    crv_hist_price_requests = requests.get(crv_hist_url)
    
    crv_price_hist = crv_hist_price_requests.json()['prices']
    cvx_price_hist = cvx_hist_price_requests.json()['prices']
    
    crv_price_df = pd.DataFrame(crv_price_hist, columns = ['ux_datetime', 'crv_price'])
    cvx_price_df = pd.DataFrame(cvx_price_hist, columns = ['ux_datetime', 'cvx_price'])
    
    price_hist_df = pd.merge(crv_price_df, cvx_price_df, on = 'ux_datetime')
    
    price_hist_df['date'] = price_hist_df.ux_datetime.apply(lambda x: pd.to_datetime(x, unit='ms', utc=True).strftime("%Y-%m-%d"))
    
    return(price_hist_df)

# %%
def join_pricing_blockchain_data(price_hist_df, pool_calcs_df_dict):
    
    # price_block_df = pd.merge(price_hist_df, block_timestamp_df, on = 'date', how = 'left').drop(['ux_datetime', 'timestamp'], axis = 1)
    
    # price_block_nona_df = price_block_df.dropna()
    # price_block_nona_df['block'] = price_block_nona_df['block'].astype(int)
    
    for pool in pool_calcs_df_dict.keys():
        # print(pool)
        pool_calcs_df_dict[pool] = pd.merge(price_hist_df, pool_calcs_df_dict[pool].copy(), on = 'date', how = 'right')
        pool_calcs_df_dict[pool] = pool_calcs_df_dict[pool].drop_duplicates('date', keep = 'last')
    
    return(pool_calcs_df_dict)

# %%
def calculate_apy(pool_calcs_df_dict):
    
    for pool in pool_calcs_df_dict.keys():
        # print(pool)
        # rewards apy
        pool_calcs_df_dict[pool]['crv_apy'] = pool_calcs_df_dict[pool]['crvPerYear'] * pool_calcs_df_dict[pool]['crv_price']
        pool_calcs_df_dict[pool]['cvx_apy'] = pool_calcs_df_dict[pool]['cvxPerYear'] * pool_calcs_df_dict[pool]['cvx_price']
        pool_calcs_df_dict[pool]['rewards_apy'] = pool_calcs_df_dict[pool]['crv_apy'] + pool_calcs_df_dict[pool]['cvx_apy']

        # base apy
        pool_calcs_df_dict[pool]['base_apr'] = (pool_calcs_df_dict[pool].virtualPrice - pool_calcs_df_dict[pool].virtualPrice.shift(1)) / pool_calcs_df_dict[pool].virtualPrice.shift(1)
        pool_calcs_df_dict[pool]['base_apy'] = ((1 + pool_calcs_df_dict[pool].base_apr) ** 365) - 1

        # total apy
        pool_calcs_df_dict[pool]['total_apy'] = pool_calcs_df_dict[pool]['rewards_apy'] + pool_calcs_df_dict[pool]['base_apy']
        
        pool_calcs_df_dict[pool].date = pd.to_datetime(pool_calcs_df_dict[pool].date, format='%Y-%m-%d')
        
    return(pool_calcs_df_dict)

# %%
def main(pool_df_dict):
    
    pool_calcs_df_dict = calculate_crv_cvx_perYear(pool_df_dict)
    price_hist_df = get_crv_cvx_historical_price(days=365)
    # block_timestamp_df = get_block_timestamp_data()
    
    pool_calcs_df_dict = join_pricing_blockchain_data(price_hist_df, pool_calcs_df_dict)
    
    pool_calcs_df_dict = calculate_apy(pool_calcs_df_dict)
    
    return(pool_calcs_df_dict)

# %%
apys_for_viz = main(df_dict)
# Out:
# frax
# ousd
# mim
# susd
# alusd
# ust-wormhole
# ironbank
# fei

# %% [markdown]
# ## Visualizations

# %%
def visualize_apy(name, data):
    df = data_.sort_values(by = 'date')
    df['7d_Total_APY'] = df.total_apy.rolling(7).mean()
    df['30d_Total_APY'] = df.total_apy.rolling(30).mean()

    # line plots
    fig, axs = plt.subplots(2, 1)
    fig.suptitle(name, fontsize = 20)
    
    axs[0].set_title('APYs')
    axs[0].plot('date', 'base_apy', data = df)
    axs[0].plot('date', 'rewards_apy', data = df)
    axs[0].plot('date', 'total_apy', data = df)
    axs[0].legend()   

    axs[1].set_title('Moving Averages')
    axs[1].plot('date', '7d_Total_APY', data=df)
    axs[1].plot('date', '30d_Total_APY', data=df)
    axs[1].plot('date', 'total_apy', data=df)
    axs[1].legend()

    fig.set_size_inches(18.5, 10.5)
    plt.show()

# %% [markdown]
# ### Pick pools here (only in-use pools available right now)

# %%
apy_strategies_ma = ['frax', 'ousd', 'mim', 'susd', 'alusd', 'ust-wormhole', 'ironbank']
# fei breaks at 14 days

# %%
pool_apy_date = pd.concat(apys_for_viz)[['total_apy', 'date']].reset_index().rename(columns = {'level_0': 'pool'}).drop('level_1', axis = 1)
pool_apy_date = pool_apy_date.pivot(index = 'date', columns='pool', values = 'total_apy')[apy_strategies_ma]

# %%
# rolling average calculations
pool_apy_ma_dict = {}
pool_apy_ma_dict[7] = pool_apy_date.rolling(7).mean()
pool_apy_ma_dict[14] = pool_apy_date.rolling(14).mean()
pool_apy_ma_dict[30] = pool_apy_date.rolling(30).mean()

ma_dict = {}
for avg in pool_apy_ma_dict.keys():
    print(avg)
    ma_dict[avg] = pool_apy_ma_dict[avg].dropna().iloc[-1].sort_values(ascending=False).mul(100).round(2)
# Out:
# 7
# 14
# 30

# %%
pd.concat(ma_dict, axis = 1).reset_index().sort_values(by = 7, ascending=False)
# Out:
#            pool      7     14     30
# 0  ust-wormhole  12.26  12.55  15.77
# 1           mim  11.55  11.64  14.00
# 2         alusd   7.40   8.00   7.27
# 3          frax   7.33   7.75   8.72
# 4      ironbank   5.74   6.08   7.36
# 5          susd   5.42   5.41   6.28
# 6          ousd   4.56   4.55   7.56

# %% [markdown]
# ## 7 Day Moving Average

# %%
# most recent day's data
pool_apy_ma_dict[7].dropna().iloc[-1].sort_values(ascending=False).mul(100).round(2)
# Out:
# pool
# ust-wormhole    12.26
# mim             11.55
# alusd            7.40
# frax             7.33
# ironbank         5.74
# susd             5.42
# ousd             4.56
# Name: 2022-03-03 00:00:00, dtype: float64

# %%
pool_apy_ma_dict[7].plot(figsize = (20,11))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 14 Day Moving Average

# %%
# most recent day's data
pool_apy_ma_dict[14].dropna().iloc[-1].sort_values(ascending=False).mul(100).round(2)
# Out:
# pool
# ust-wormhole    12.55
# mim             11.64
# alusd            8.00
# frax             7.75
# ironbank         6.08
# susd             5.41
# ousd             4.55
# Name: 2022-03-03 00:00:00, dtype: float64

# %%
pool_apy_ma_dict[14].plot(figsize = (20,11))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 30 Day Moving Average

# %%
# most recent day's data
pool_apy_ma_dict[30].dropna().iloc[-1].sort_values(ascending=False).mul(100).round(2)
# Out:
# pool
# ust-wormhole    15.77
# mim             14.00
# frax             8.72
# ousd             7.56
# ironbank         7.36
# alusd            7.27
# susd             6.28
# Name: 2022-03-03 00:00:00, dtype: float64

# %%
pool_apy_ma_dict[30].plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Pool Specific Views

# %%
apy_strategies = ['frax', 'ousd', 'mim', 'susd', 'alusd', 'ust-wormhole', 'ironbank', 'fei']
# fei breaks at 30 days

# %%
for pool in apy_strategies:
    print(pool)
    data_ = apys_for_viz[pool]
    visualize_apy(f'{pool}', data_)
# Out:
# frax
# ousd
# mim
# susd
# alusd
# ust-wormhole
# ironbank
# fei
